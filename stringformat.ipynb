# %%
name="Dipthamshu"
age=22
marks=[10,20,30,50]
print("My name is  %s  age is %d years "%(name,age))
# Out:
# My name is  Dipthamshu  age is 22 years

# %%
#dot format
name="ravi"
age=22
marks=[20,34,54,55]
print("my name is {} and i am a {} years old".format(name,age))
# Out:
# my name is ravi and i am a 22 years old

# %%
# f-format
name="ravi"
age=22
marks=[20,34,54,55]
percentage = 76.9998766
print(f"my name is {name} and i am a {age} years old")
print(f"my name is {name} and i am a {age} years old and percentage is {percentage:.2f}"
# Out:
# my name is ravi and i am a 22 years old
# my name is ravi and i am a 22 years old and percentage is 77.00
