# %%
#local scope
# we can acces the local scope variable within in the scope , we cant access in global scope
def fun(x):
    x=x+1
    return x
a=10
res = fun(a)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3     x=x+1
#       4     return x
#       5 a=10
#       6 res = fun(a)
# ----> 7 print(x)
#
# NameError: name 'x' is not defined

# %%
#enclosing scope 
def outer(x):
    y=10
    def inner():
        a=10
        z=y+a
        print(f"this is local scope:{z}")
    inner()
    y=y+x
    print(f"this is enclosing:{y}")
n=5
outer(n)
# Out:
# this is local scope:20
# this is enclosing:15

# %%
x=10
def outer():
    y=20
    def inner():
        z=30
        res=z+y+x
        print(f"this is local scope:{res}")
    res =y+x
    inner()
    print(f"this is enclosing:{res}")

outer()
# Out:
# this is local scope:60
# this is enclosing:30
