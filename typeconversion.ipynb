# %%
#reading integer from user
#integer to float , string,bool
n=input()
print(type(n))
# Out:
#  3
# <class 'str'>

# %%
n=  int(input())
print(type(n),n)
print(float(n))
print(str(n))
print(bool(n))
# Out:
#  25
# <class 'int'> 25
# 25.0
# 25
# True

# %%
val = float(input())
print(type(val),val)
print(int(val))
print(str(val))
print(bool(val))
# Out:
#  20.5
# <class 'float'> 20.5
# 20
# 20.5
# True

# %%
real =int(input())
ima=int(input())
c= complex(real,ima)
print(type(c),c)
# Out:
#  4
#  7
# <class 'complex'> (4+7j)

# %%
s=input()#123
print(type(s),s)
print(int(s))
print(float(s))
print(list(s))
print(tuple(s))
print(set(s))
# Out:
#  907876556789
# <class 'str'> 907876556789
# 907876556789
# 907876556789.0
# ['9', '0', '7', '8', '7', '6', '5', '5', '6', '7', '8', '9']
# ('9', '0', '7', '8', '7', '6', '5', '5', '6', '7', '8', '9')
# {'7', '6', '9', '0', '5', '8'}

# %%
s=input()#dipthamshu
print(type(s),s)
l=list(s)
print(l[2:])
print(tuple(s))
print(set(s))
# Out:
#  dipthamshuthakur
# <class 'str'> dipthamshuthakur
# ['p', 't', 'h', 'a', 'm', 's', 'h', 'u', 't', 'h', 'a', 'k', 'u', 'r']
# ('d', 'i', 'p', 't', 'h', 'a', 'm', 's', 'h', 'u', 't', 'h', 'a', 'k', 'u', 'r')
# {'i', 'r', 't', 'p', 'h', 'a', 'm', 'u', 's', 'd', 'k'}

# %%
s= map(int,input().split())
print(list(s))
# Out:
#  1234
# [1234]

# %%
l =list(map(int,input().split()))
print(l)
print(tuple(l))
print(Set(l))
# Out:
#   Cell In[20], line 4
#     print(Set(l)
#                 ^
# _IncompleteInputError: incomplete input

# %%
)
