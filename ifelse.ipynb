# %%
n=int(input("enter a number: "))
if n%2==0:
    print(f"{n} is even")
if n%2!=0:
    print(f"{n} is odd")
# Out:
# enter a number:  55
# 55 is odd

# %%
n=int(input("enter a number: "))
if n%3==0:
    print("fizz")
if n%5==0:
    print("buzz")
else:
    print(n)
# Out:
# enter a number:  79
# 79

# %%
n=int(input())
if n>0:
    print("positive")
elif n==0:
    print("zero")
else:
    print("negetive")
# Out:
#  -2
# negetive

# %%
n=int(input())
if n%3==0 and n%5==0:
    
    print("fizzbuzz")
elif n%5==0:
    print("buzz")
elif n%3==0:
    print("fizz")
    
else:
    print(n)
# Out:
#  90
# fizzbuzz

# %%
n=int(input())
if n>0 and n%2==0:
    print("positive even")
elif n>0 :
    print("positive odd")
elif n<0 and n%2==0:
    print("negetive even")
elif n<0 :
    
    print("negetive odd")
else:
    print("zero")
# Out:
#  5
# positive odd

# %%
n=int(input())
n1=int(input())
n2=int(input())
s=min(n,n1,n2)
print(s)
# Out:
#  1
#  2
#  3
# 1

# %%
n=int(input())
n1=int(input())
n2=int(input())
if n<=n1 and n<=n2:
    print(f"smallest={n} found at n")
elif  n1<=n2:
    print(f"smallest={n1} found at n1")
else:
    print(f"smallest={n2} found at n2")
# Out:
#  1
#  3
#  0
# smallest=0 found at n2

# %%
n=int(input())
if n>0:
    if n%2==0:
        print("positive even")
    else:
        print("positive odd")
else:
    if n%2==0:
        print("neg even")
    else:
        print("neg odd")
# Out:
#  -2
# neg even

# %%
n=int(input())
n1=int(input())
n2=int(input())
if  n<=n1:
    if n<n2:#
        print(f"{n} is small")
    else:
        print(f"{n2} is small")
else:
    if n1<=n2:
        print(f"{n1} is small")
    else:
        print(f"{n2} is small")
# Out:
#  2
#  3
#  1
# 1 is small
