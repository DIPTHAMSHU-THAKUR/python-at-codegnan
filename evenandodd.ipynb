# %%
even,odd=2,1
for r in range(1,4):
    for c in range(1,4):
        if r%2==0:
            print(odd,end="\t")
            odd+=2
        else:
            print(even,end="\t")
            even+=2
    print()
# Out:
# 2	4	6
# 1	3	5
# 8	10	12

# %%
n=4
for r in range(1,n+1):
    for c in range(r):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *

# %%
n=4
for r in range(1,n+1):
    for c in range(1,n+1):
        if r>=c:
            print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *

# %%
n=4
for r in range(1,n+1):
    for c in range(1,n+1):
        if r==c:
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# *
#   *
#     *
#       *

# %%
n=4

for r in range(1,n+1):
    for c in range(1,n+1):
        if c==n-r+1:
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
#       *
#     *
#   *
# *

# %%
n=3

for i in range(1,n+1):
    for j in range(n-i):
        print(" ",end=" ")
    for k in range(2*i-1):
        print("*",end=" ")
    print()
# Out:
#     *
#   * * *
# * * * * *

# %%
n=3
for i in range(n,0,-1):  #3,0,-1 3,2,1
    
    for j in range(n-i): #]=
        print(" ",end=" ")
    for k in range(2*i-1):
        print("*",end=" ")
    print()
# Out:
# * * * * *
#   * * *
#     *

# %%
n=5

for i in range(1,n+1):
    for j in range(n-i):
        print(" ",end=" ")
    for k in range(2*i-1):
        print("*",end=" ")
    print()
for i in range(n-1,0,-1):  
    
    for j in range(n-i): 
        print(" ",end=" ")
    for k in range(2*i-1):
        print("*",end=" ")
    print()
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %%
n=5
for i in range(n):
    print("  "*(n-i-1)+" *"*(2*i+1))
for i in range(n-2,-1,-1):
    print("  "*(n-i-1)+" *"*(2*i+1))
print()
# Out:
#          *
#        * * *
#      * * * * *
#    * * * * * * *
#  * * * * * * * * *
#    * * * * * * *
#      * * * * *
#        * * *
#          *

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if j==n-i+1 or i==j:
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# *       *
#   *   *
#     *
#   *   *
# *       *

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if i==j or j==1 or j==n:
            print("*",end=" ")
        else:print(" ",end=" ")
    print()
# Out:
# *       *
# * *     *
# *   *   *
# *     * *
# *       *

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if (i==j and i<=n//2) or j==n-i+1:
            print("*",end=" ")
        else:print(" ",end=" ")
    print()
# Out:
# *       *
#   *   *
#     *
#   *
# *

# %%
n=5
for i in range(1,n+1):
    for j in range(1,n+1):
        if (i==j and i<=n//2) or (i + j == n - 1 and i <= n // 2) or j==1 or j==n:
            print("*",end=" ")
        else:print(" ",end=" ")
    print()
# Out:
# *   *   *
# * *     *
# *       *
# *       *
# *       *
